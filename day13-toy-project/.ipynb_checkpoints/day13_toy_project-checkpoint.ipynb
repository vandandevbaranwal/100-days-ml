# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:/Users/vanda/Desktop/100-days-ml/day13-toy-project/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 3)

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement']) #EDA

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 63   6.3  128.0
# 56   6.1   65.0
# 93   6.8  112.0
# 21   7.1  151.0
# 74   6.7  154.0
# ..   ...    ...
# 31   3.9  109.0
# 25   5.0   91.0
# 44   7.5   61.0
# 6    5.7  143.0
# 72   7.3  116.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 63    1
# 56    0
# 93    1
# 21    1
# 74    1
#      ..
# 31    0
# 25    0
# 44    1
# 6     0
# 72    1
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 98   6.3  103.0
# 57   6.5  130.0
# 89   4.9  151.0
# 55   7.8  114.0
# 43   6.8  141.0
# 79   6.5   90.0
# 3    7.4  132.0
# 9    5.1   66.0
# 49   5.4  135.0
# 19   5.2  132.0

# %%
y_test
# Out:
# 98    1
# 57    1
# 89    0
# 55    1
# 43    1
# 79    1
# 3     1
# 9     0
# 49    0
# 19    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 2.86806938e-01,  9.63745159e-02],
#        [ 1.13567848e-01, -1.43857915e+00],
#        [ 7.19904664e-01, -2.93454987e-01],
#        [ 9.79763300e-01,  6.56754426e-01],
#        [ 6.33285119e-01,  7.29847457e-01],
#        [ 6.33285119e-01,  1.41204909e+00],
#        [ 2.69483029e-02, -1.41421481e+00],
#        [ 2.69483029e-02,  6.08025738e-01],
#        [-1.70544260e+00, -5.85827113e-01],
#        [ 1.13567848e-01,  1.93831891e-01],
#        [-5.79388513e-01, -7.41758914e-02],
#        [-5.79388513e-01, -2.44726299e-01],
#        [ 4.60046029e-01, -2.12078078e+00],
#        [-1.18572533e+00,  5.34932706e-01],
#        [ 4.60046029e-01,  8.76033521e-01],
#        [ 8.06524209e-01, -6.83284489e-01],
#        [-6.66008058e-01, -8.29470552e-01],
#        [-1.35896442e+00, -1.99895906e+00],
#        [ 1.13567848e-01, -1.04874965e+00],
#        [ 2.69483029e-02, -1.92586603e+00],
#        [ 3.73426484e-01,  4.13110987e-01],
#        [ 1.15300239e+00, -1.80404431e+00],
#        [-4.92768968e-01,  3.64382299e-01],
#        [-8.39247149e-01, -1.48730784e+00],
#        [-9.25866694e-01,  2.42560579e-01],
#        [-1.01248624e+00,  1.09531262e+00],
#        [ 1.41286103e+00, -8.53834896e-01],
#        [ 2.00187393e-01, -2.69090643e-01],
#        [ 8.93143754e-01,  1.82624293e+00],
#        [ 3.73426484e-01, -1.95997611e-01],
#        [ 2.86806938e-01,  7.20101720e-02],
#        [-1.70544260e+00, -1.19493571e+00],
#        [ 8.93143754e-01,  1.24149868e+00],
#        [-8.39247149e-01, -1.47268923e-01],
#        [ 1.84595875e+00,  6.08025738e-01],
#        [ 8.06524209e-01,  3.64382299e-01],
#        [-1.01248624e+00,  9.49126552e-01],
#        [-2.13854033e+00,  2.65463063e+00],
#        [-1.09910578e+00, -1.75531562e+00],
#        [ 1.15300239e+00, -9.26927928e-01],
#        [ 1.15300239e+00,  3.15653611e-01],
#        [ 5.46665574e-01,  3.40017955e-01],
#        [-6.66008058e-01, -3.42183674e-01],
#        [ 1.13567848e-01, -5.12734082e-01],
#        [-1.09910578e+00, -9.02563584e-01],
#        [-7.52627603e-01,  1.26586302e+00],
#        [ 7.19904664e-01, -2.54472036e-02],
#        [ 2.01919784e+00,  1.07094827e+00],
#        [ 2.69483029e-02, -5.37098426e-01],
#        [ 1.41286103e+00,  9.63745159e-02],
#        [-9.25866694e-01,  7.54211801e-01],
#        [-1.01248624e+00,  4.13110987e-01],
#        [-7.52627603e-01,  9.63745159e-02],
#        [-1.35896442e+00,  6.08025738e-01],
#        [-1.01248624e+00, -2.93454987e-01],
#        [-1.46290787e-01,  1.02221958e+00],
#        [ 8.93143754e-01, -1.46294349e+00],
#        [-5.96712422e-02, -4.39641050e-01],
#        [ 2.19243693e+00, -9.85402353e-02],
#        [-9.25866694e-01, -9.85402353e-02],
#        [-2.32910332e-01,  1.09531262e+00],
#        [ 8.93143754e-01,  3.64382299e-01],
#        [ 1.75933921e+00, -1.09747834e+00],
#        [-2.32910332e-01,  1.93831891e-01],
#        [-6.66008058e-01,  9.00397865e-01],
#        [ 8.06524209e-01,  3.40017955e-01],
#        [ 7.19904664e-01, -8.29470552e-01],
#        [-4.92768968e-01, -2.44726299e-01],
#        [-1.44558396e+00,  1.85060728e+00],
#        [ 1.32624148e+00,  8.27304833e-01],
#        [-2.32910332e-01,  3.88746643e-01],
#        [-1.09910578e+00, -7.41758914e-02],
#        [ 9.79763300e-01, -1.85277300e+00],
#        [-2.31177942e+00,  1.43641343e+00],
#        [-9.25866694e-01,  1.75314990e+00],
#        [ 1.32624148e+00,  1.45103204e-01],
#        [-1.46290787e-01,  4.37475331e-01],
#        [ 5.46665574e-01, -9.85402353e-02],
#        [ 1.13567848e-01,  7.78576145e-01],
#        [ 1.84595875e+00,  1.02221958e+00],
#        [-9.25866694e-01, -1.53603653e+00],
#        [ 2.69483029e-02, -1.08285973e-03],
#        [ 8.93143754e-01, -2.93454987e-01],
#        [-6.66008058e-01,  2.43535153e+00],
#        [-4.92768968e-01, -4.15276706e-01],
#        [-1.79206215e+00, -3.66548018e-01],
#        [-8.39247149e-01, -8.05106209e-01],
#        [ 1.32624148e+00, -1.53603653e+00],
#        [-2.32910332e-01,  4.61839674e-01],
#        [ 1.15300239e+00, -1.95997611e-01]])

# %%
X_test= scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.28680694, -0.51273408],
#        [ 0.46004603,  0.1451032 ],
#        [-0.92586669,  0.65675443],
#        [ 1.58610012, -0.2447263 ],
#        [ 0.71990466,  0.41311099],
#        [ 0.46004603, -0.82947055],
#        [ 1.23962193,  0.19383189],
#        [-0.7526276 , -1.41421481],
#        [-0.49276897,  0.26692492],
#        [-0.66600806,  0.19383189]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf= LogisticRegression()

# %%
clf.fit(X_train,y_train) #model training
# Out:
# LogisticRegression()

# %%
y_pred= clf.predict(X_test)

# %%
y_test
# Out:
# 98    1
# 57    1
# 89    0
# 55    1
# 43    1
# 79    1
# 3     1
# 9     0
# 49    0
# 19    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
